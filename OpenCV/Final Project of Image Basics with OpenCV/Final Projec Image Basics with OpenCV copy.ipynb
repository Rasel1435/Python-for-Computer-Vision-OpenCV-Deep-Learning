# %% [markdown]
# Task: Open the 01.jpg image from IMAGE folder and display in the notebook. Make Sure to correct for the RGB order.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
# %matplotlib inline

# %%
img = cv2.imread("image/01.jpg")

# %%
plt.imshow(img)

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %% [markdown]
# TASK: Flip the image upside down and display it in the notebook

# %%
new_img = rgb_img.copy()

# %%
new_img = cv2.flip(new_img,0)
plt.imshow(new_img)

# %% [markdown]
# Task: Drwa an empty RED rectangle aaround the dogs face and display the image in the notebook

# %%
cv2.rectangle(rgb_img, pt1=(150,250), pt2=(580,700), color=(255,0,0), thickness=10)
plt.imshow(rgb_img)

# %% [markdown]
# Task: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle(three sides) in any orientation.

# %%
vertiecs = np.array([ [150,700],[380,250],[580,700] ])

# %%
vertiecs.shape
# Out:
# (3, 2)

# %%
pts = vertiecs.reshape(-1,1,2)

# %%
vertiecs
# Out:
# array([[150, 700],
#        [380, 250],
#        [580, 700]])

# %%
pts
# Out:
# array([[[150, 700]],
#
#        [[380, 250]],
#
#        [[580, 700]]])

# %%
pts.shape
# Out:
# (3, 1, 2)

# %%
cv2.polylines(rgb_img,[pts],isClosed=True, color=(0,0,255), thickness=20)
plt.imshow(rgb_img)

# %% [markdown]
# TASK: Can you figure out how to fill in this triangle? it requires a diffrent function that we didn't show in the lecture! See if you can use google search to find it.

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.fillPoly(rgb_img,[pts], color=(0,0,255))
plt.imshow(rgb_img)

# %% [markdown]
# LAST TASK: YOU WILL NEED TO RUN THIS AS A SCRIPT. Create a script that opens the picture and allows you to draw empty red circle whenever you click the RIGHT MOUSE BUTTON DOWN.

# %%
import numpy as np
import cv2

def create_circle(event,x,y,flag,param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img, (x,y), radius=100, color=(0,0,255), thickness=10)


cv2.namedWindow(winname=("dog"))
cv2.setMouseCallback("dog", create_circle)
img = cv2.imread("image/01.jpg")


while True:

    cv2.imshow("dog",img)
    if cv2.waitKey(20) & 0xFF == 27:
        break


cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# g:\HR Venture\Git\Python\Data Science & Machine Learing and Deep Learning\OpenCV\Final Project of Image Basics with OpenCV\Final Projec Image Basics with OpenCV copy.ipynb Cell 22' in <module>
#      <a href='vscode-notebook-cell:/g%3A/HR%20Venture/Git/Python/Data%20Science%20%26%20Machine%20Learing%20and%20Deep%20Learning/OpenCV/Final%20Project%20of%20Image%20Basics%20with%20OpenCV/Final%20Projec%20Image%20Basics%20with%20OpenCV%20copy.ipynb#ch0000021?line=13'>14</a> while True:
#      <a href='vscode-notebook-cell:/g%3A/HR%20Venture/Git/Python/Data%20Science%20%26%20Machine%20Learing%20and%20Deep%20Learning/OpenCV/Final%20Project%20of%20Image%20Basics%20with%20OpenCV/Final%20Projec%20Image%20Basics%20with%20OpenCV%20copy.ipynb#ch0000021?line=15'>16</a>     cv2.imshow("dog",img)
# ...
