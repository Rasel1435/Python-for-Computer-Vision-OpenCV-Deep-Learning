# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r"OpenCV\Image Basics with OpenCV\Images\SRA.png")

# %%
# You have to always check this type if your path are wrong then it will show "NoneType"
type(img)
# Out:
# NoneType

# %%
img = cv2.imread(r".\Images\SRA.png")

# %%
# if your path are correct then it will show "numpy.ndarry"
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (2048, 1536, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> RGB RED, GREEN, BLUE
# OPENCV --->BLUE, GREEN, RED

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
gry_img = cv2.imread(r".\Images\SRA.png", cv2.IMREAD_GRAYSCALE)

# %%
gry_img.shape
# Out:
# (2048, 1536)

# %%
plt.imshow(gry_img, cmap='gray')

# %%
#This is our orginal image
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (2048, 1536, 3)

# %%
resize_img = cv2.resize(fix_img, (1024,768))

# %%
plt.imshow(resize_img)

# %%
# w_ratio = 0.8
# h_ratio = 0.2 # 20% of orginal height

w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img,(0,0), fix_img, w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (1024, 768, 3)

# %%
new_img = cv2.flip(fix_img, 0) 
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img, 1) 
plt.imshow(new_img)

# %% [markdown]
# See The Diffrent

# %%
new_img = cv2.flip(fix_img, -1) 
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %% [markdown]
# For save Image File

# %%
cv2.imwrite('Images\save.png', fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
